# %%
# Fase 5

# %%
import os

# Crear carpeta warehouse
os.makedirs("warehouse", exist_ok=True)

# Contenido SQL de las tablas
sql_content = """
CREATE TABLE dim_clientes (
    customer_id INTEGER PRIMARY KEY,
    customer_name VARCHAR(255) NOT NULL
);

CREATE TABLE dim_productos (
    product_id INTEGER PRIMARY KEY,
    product_name VARCHAR(255) NOT NULL,
    category VARCHAR(100) NOT NULL
);

CREATE TABLE fact_pedidos (
    order_id INTEGER PRIMARY KEY,
    customer_id INTEGER,
    product_id INTEGER,
    order_date DATE,
    quantity INTEGER,
    unit_price DECIMAL(10,2),
    total_price DECIMAL(10,2),
    payment_method VARCHAR(50),
    country VARCHAR(100),
    city VARCHAR(100),
    status VARCHAR(50),
    update_time TIMESTAMP,
    
    FOREIGN KEY (customer_id) REFERENCES dim_clientes(customer_id),
    FOREIGN KEY (product_id) REFERENCES dim_productos(product_id)
);
"""
# Crear los dos archivos (mismo contenido pero tratados de diferente forma)
with open("warehouse/modelo_datawarehouse_pandas.sql", "w") as f:
    f.write(sql_content)
    
with open("warehouse/modelo_datawarehouse_pyspark.sql", "w") as f:
    f.write(sql_content)

print("✅ Archivos creados:")
print("- warehouse/modelo_datawarehouse_pandas.sql")
print("- warehouse/modelo_datawarehouse_pyspark.sql")
# Out:
# ✅ Archivos creados:
# - warehouse/modelo_datawarehouse_pandas.sql
# - warehouse/modelo_datawarehouse_pyspark.sql
